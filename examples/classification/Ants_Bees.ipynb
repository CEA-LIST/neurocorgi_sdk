# %% [markdown]
# This example shows you how to use the NeuroCorgi model with N2D2
#
# First be sure to install N2D2 in your environment before running the above cells
# ```bash
# # Installing N2D2
# git clone --recursive https://github.com/CEA-LIST/N2D2.git
# cd N2D2
# pip install .
# ```

# %%
import n2d2
import torch
import matplotlib.pyplot as plt
import numpy as np
import torch.nn.functional as F
from torch import nn
from torchvision import datasets, transforms
from neurocorgi_sdk import NeuroCorgiNet_n2d2_torch

# %%
# If possible, set up the GPU 0 for the application
device_id = 0
device = torch.device(f"cuda:{device_id}" if torch.cuda.is_available() else "cpu")

n2d2.global_variables.default_model = "Frame_CUDA" if n2d2.global_variables.cuda_available else "Frame"
n2d2.global_variables.cuda_device = device_id

n2d2.global_variables.verbosity = 0

# %%
# !git clone https://github.com/jaddoescad/ants_and_bees.git
# Out:
# fatal: destination path 'ants_and_bees' already exists and is not an empty directory.

# %%
# !ls ants_and_bees
# Out:
# train  val

# %%
# !ls ants_and_bees/train
# Out:
# ants  bees

# %%
# !ls ants_and_bees/train/ants
# Out:
#  0013035.jpg		     408393566_b5b694119b.jpg
#  1030023514_aad5c608f9.jpg   424119020_6d57481dab.jpg
#  1095476100_3906d8afde.jpg   424873399_47658a91fb.jpg
#  1099452230_d1949d3250.jpg   450057712_771b3bfc91.jpg
#  116570827_e9c126745d.jpg    45472593_bfd624f8dc.jpg
#  1225872729_6f0856588f.jpg   459694881_ac657d3187.jpg
#  1262877379_64fcada201.jpg   460372577_f2f6a8c9fc.jpg
#  1269756697_0bce92cdab.jpg   460874319_0a45ab4d05.jpg
#  1286984635_5119e80de1.jpg   466430434_4000737de9.jpg
#  132478121_2a430adea2.jpg    470127037_513711fd21.jpg
#  1360291657_dc248c5eea.jpg   474806473_ca6caab245.jpg
#  1368913450_e146e2fb6d.jpg   475961153_b8c13fd405.jpg
#  1473187633_63ccaacea6.jpg   484293231_e53cfc0c89.jpg
#  148715752_302c84f5a4.jpg    49375974_e28ba6f17e.jpg
#  1489674356_09d48dde0a.jpg   506249802_207cd979b4.jpg
#  149244013_c529578289.jpg    506249836_717b73f540.jpg
#  150801003_3390b73135.jpg    512164029_c0a66b8498.jpg
#  150801171_cd86f17ed8.jpg    512863248_43c8ce579b.jpg
#  154124431_65460430f2.jpg    518773929_734dbc5ff4.jpg
#  162603798_40b51f1654.jpg    522163566_fec115ca66.jpg
#  1660097129_384bf54490.jpg   522415432_2218f34bf8.jpg
#  167890289_dd5ba923f3.jpg    531979952_bde12b3bc0.jpg
#  1693954099_46d4c20605.jpg   533848102_70a85ad6dd.jpg
#  175998972.jpg		     535522953_308353a07c.jpg
#  178538489_bec7649292.jpg    540889389_48bb588b21.jpg
#  1804095607_0341701e1c.jpg   541630764_dbd285d63c.jpg
#  1808777855_2a895621d7.jpg   543417860_b14237f569.jpg
#  188552436_605cc9b36b.jpg    560966032_988f4d7bc4.jpg
#  1917341202_d00a7f9af5.jpg   5650366_e22b7e1065.jpg
#  1924473702_daa9aacdbe.jpg   6240329_72c01e663e.jpg
#  196057951_63bf063b92.jpg    6240338_93729615ec.jpg
#  196757565_326437f5fe.jpg    649026570_e58656104b.jpg
#  201558278_fe4caecc76.jpg    662541407_ff8db781e7.jpg
#  201790779_527f4c0168.jpg    67270775_e9fdf77e9d.jpg
#  2019439677_2db655d361.jpg   6743948_2b8c096dda.jpg
#  207947948_3ab29d7207.jpg    684133190_35b62c0c1d.jpg
#  20935278_9190345f6b.jpg     69639610_95e0de17aa.jpg
#  224655713_3956f7d39a.jpg    707895295_009cf23188.jpg
#  2265824718_2c96f485da.jpg   7759525_1363d24e88.jpg
#  2265825502_fff99cfd2d.jpg   795000156_a9900a4a71.jpg
#  226951206_d6bf946504.jpg    822537660_caf4ba5514.jpg
#  2278278459_6b99605e50.jpg   82852639_52b7f7f5e3.jpg
#  2288450226_a6e96e8fdf.jpg   841049277_b28e58ad05.jpg
#  2288481644_83ff7e4572.jpg   886401651_f878e888cd.jpg
#  2292213964_ca51ce4bef.jpg   892108839_f1aad4ca46.jpg
#  24335309_c5ea483bb8.jpg     938946700_ca1c669085.jpg
#  245647475_9523dfd13e.jpg    957233405_25c1d1187b.jpg
#  255434217_1b2b3fe0a4.jpg    9715481_b3cb4114ff.jpg
#  258217966_d9d90d18d3.jpg    998118368_6ac1d91f81.jpg
#  275429470_b2d7d9290b.jpg    Ant_1.jpg
#  28847243_e79fe052cd.jpg     MehdiabadiAnt2_600.jpg
#  318052216_84dff3f98a.jpg    Nepenthes_rafflesiana_ant.jpg
#  334167043_cbd1adaeb9.jpg    VietnameseAntMimicSpider.jpg
#  339670531_94b75ae47a.jpg   'ant photos.jpg'
#  342438950_a3da61deab.jpg    army-ants-red-picture.jpg
#  36439863_0bec9f554f.jpg     formica.jpeg
#  374435068_7eee412ec4.jpg    hormiga_co_por.jpg
#  382971067_0bfd33afe0.jpg    imageNotFound.gif
#  384191229_5779cf591b.jpg    kurokusa.jpg
#  386190770_672743c9a7.jpg    swiss-army-ant.jpg
#  392382602_1b7bed32fa.jpg    termite-vs-ant.jpg
#  403746349_71384f5b58.jpg    trap-jaw-ant-insect-bg.jpg

# %% [markdown]
# Important: no need to specify the ToNeuroCorgiChip transformation because the n2d2 version of NeuroCorgiNet already applies chip transformations

# %%
transform_train = transforms.Compose([transforms.Resize((224,224)),
                                      transforms.RandomHorizontalFlip(),
                                      transforms.RandomAffine(0, shear=10, scale=(0.8,1.2)),
                                      transforms.ColorJitter(brightness=1, contrast=1, saturation=1),
                                      transforms.ToTensor(),
                                      transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
                               ])


transform = transforms.Compose([transforms.Resize((224,224)),
                               transforms.ToTensor(),
                               transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
                               ])

training_dataset = datasets.ImageFolder('ants_and_bees/train', transform=transform_train)
validation_dataset = datasets.ImageFolder('ants_and_bees/val', transform=transform)

training_loader = torch.utils.data.DataLoader(training_dataset, batch_size=20, shuffle=True, drop_last=True)
validation_loader = torch.utils.data.DataLoader(validation_dataset, batch_size = 20, shuffle=True, drop_last=True)

# %%
print(len(training_dataset))
print(len(validation_dataset))
# Out:
# 244
# 153

# %%
def im_convert(tensor):
    image = tensor.cpu().clone().detach().numpy()
    image = image.transpose(1, 2, 0)
    image = image * np.array((0.5, 0.5, 0.5)) + np.array((0.5, 0.5, 0.5))
    image = image.clip(0, 1)
    return image

# %%
classes = ('ant', 'bee')

# %%
dataiter = iter(training_loader)
images, labels = next(dataiter)
fig = plt.figure(figsize=(25, 4))

for idx in np.arange(20):
    ax = fig.add_subplot(2, 10, idx+1, xticks=[], yticks=[])
    plt.imshow(im_convert(images[idx]))
    ax.set_title(classes[labels[idx].item()])

# %%
# For this example, we use the model pretrained and quantized with the ImageNet dataset
model = NeuroCorgiNet_n2d2_torch([20, 3, 224, 224], weights_dir="../data/imagenet_weights")
# Out:
# Importing NeuroCorgi model in int4 mode.
# Adding cell (extractor) : bn1
# Adding cell (extractor) : bn1_3x3_dw
# Adding cell (extractor) : bn1_1x1
# Adding cell (extractor) : bn2_3x3_dw
# Adding cell (extractor) : bn2_1x1
# Adding cell (extractor) : bn3_3x3_dw
# Adding cell (extractor) : bn3_1x1
# Adding cell (extractor) : bn4_3x3_dw
# Adding cell (extractor) : bn4_1x1
# Adding cell (extractor) : bn5_3x3_dw
# Adding cell (extractor) : bn5_1x1
# Adding cell (extractor) : bn6_3x3_dw
# Adding cell (extractor) : bn6_1x1
# Adding cell (extractor) : bn7_1_3x3_dw
# Adding cell (extractor) : bn7_1_1x1
# Adding cell (extractor) : bn7_2_3x3_dw
# Adding cell (extractor) : bn7_2_1x1
# Adding cell (extractor) : bn7_3_3x3_dw
# Adding cell (extractor) : bn7_3_1x1
# Adding cell (extractor) : bn7_4_3x3_dw
# Adding cell (extractor) : bn7_4_1x1
# Adding cell (extractor) : bn7_5_3x3_dw
# Adding cell (extractor) : bn7_5_1x1
# Adding cell (extractor) : bn8_3x3_dw
# Adding cell (extractor) : bn8_1x1
# Adding cell (extractor) : bn9_3x3_dw
# Adding cell (extractor) : bn9_1x1
# Import ../data/imagenet_weights/conv1.syntxt
# Import ../data/imagenet_weights/conv1_3x3_dw.syntxt
# Import ../data/imagenet_weights/conv1_1x1.syntxt
# Import ../data/imagenet_weights/bn1.syntxt
# Import ../data/imagenet_weights/bn1_3x3_dw.syntxt
# Import ../data/imagenet_weights/bn1_1x1.syntxt
# Import ../data/imagenet_weights/conv2_3x3_dw.syntxt
# Import ../data/imagenet_weights/conv2_1x1.syntxt
# Import ../data/imagenet_weights/conv3_3x3_dw.syntxt
# Import ../data/imagenet_weights/conv3_1x1.syntxt
# Import ../data/imagenet_weights/bn2_3x3_dw.syntxt
# Import ../data/imagenet_weights/bn2_1x1.syntxt
# Import ../data/imagenet_weights/bn3_3x3_dw.syntxt
# Import ../data/imagenet_weights/bn3_1x1.syntxt
# Import ../data/imagenet_weights/conv4_3x3_dw.syntxt
# Import ../data/imagenet_weights/conv4_1x1.syntxt
# Import ../data/imagenet_weights/conv5_3x3_dw.syntxt
# Import ../data/imagenet_weights/conv5_1x1.syntxt
# Import ../data/imagenet_weights/bn4_3x3_dw.syntxt
# Import ../data/imagenet_weights/bn4_1x1.syntxt
# Import ../data/imagenet_weights/bn5_3x3_dw.syntxt
# Import ../data/imagenet_weights/bn5_1x1.syntxt
# Import ../data/imagenet_weights/conv6_3x3_dw.syntxt
# Import ../data/imagenet_weights/conv6_1x1.syntxt
# Import ../data/imagenet_weights/conv7_1_3x3_dw.syntxt
# Import ../data/imagenet_weights/conv7_1_1x1.syntxt
# Import ../data/imagenet_weights/conv7_2_3x3_dw.syntxt
# Import ../data/imagenet_weights/conv7_2_1x1.syntxt
# Import ../data/imagenet_weights/conv7_3_3x3_dw.syntxt
# Import ../data/imagenet_weights/conv7_3_1x1.syntxt
# Import ../data/imagenet_weights/conv7_4_3x3_dw.syntxt
# Import ../data/imagenet_weights/conv7_4_1x1.syntxt
# Import ../data/imagenet_weights/conv7_5_3x3_dw.syntxt
# Import ../data/imagenet_weights/conv7_5_1x1.syntxt
# Import ../data/imagenet_weights/bn6_3x3_dw.syntxt
# Import ../data/imagenet_weights/bn6_1x1.syntxt
# Import ../data/imagenet_weights/bn7_1_3x3_dw.syntxt
# Import ../data/imagenet_weights/bn7_1_1x1.syntxt
# Import ../data/imagenet_weights/bn7_2_3x3_dw.syntxt
# Import ../data/imagenet_weights/bn7_2_1x1.syntxt
# Import ../data/imagenet_weights/bn7_3_3x3_dw.syntxt
# Import ../data/imagenet_weights/bn7_3_1x1.syntxt
# Import ../data/imagenet_weights/bn7_4_3x3_dw.syntxt
# Import ../data/imagenet_weights/bn7_4_1x1.syntxt
# Import ../data/imagenet_weights/bn7_5_3x3_dw.syntxt
# Import ../data/imagenet_weights/bn7_5_1x1.syntxt
# Import ../data/imagenet_weights/conv8_3x3_dw.syntxt
# Import ../data/imagenet_weights/conv8_1x1.syntxt
# Import ../data/imagenet_weights/conv9_3x3_dw.syntxt
# Import ../data/imagenet_weights/conv9_1x1.syntxt
# Import ../data/imagenet_weights/bn8_3x3_dw.syntxt
# Import ../data/imagenet_weights/bn8_1x1.syntxt
# Import ../data/imagenet_weights/bn9_3x3_dw.syntxt
# Import ../data/imagenet_weights/bn9_1x1.syntxt
# Import ../data/imagenet_weights/fc.syntxt
# CUDNN initialized on device #0
# Applying QAT Fusion...CUBLAS initialized on device #0
#
# Fuse the QAT Graph for hardware compatibility...
# stimuli_stats processing 0 stimuli

# %%
print(model)
# Out:
# 'DeepNet_0' NeuroCorgiNet_n2d2(
# 	(0): 'conv1' Conv(Frame_CUDA<float>)(nb_inputs=3, nb_outputs=32, kernel_dims=[3, 3], sub_sample_dims=[1, 1], stride_dims=[2, 2], padding_dims=[1, 1], dilation_dims=[1, 1])
# 	(1): 'conv1_3x3_dw' Conv(Frame_CUDA<float>)(nb_inputs=32, nb_outputs=32, kernel_dims=[3, 3], sub_sample_dims=[1, 1], stride_dims=[1, 1], padding_dims=[1, 1], dilation_dims=[1, 1])(['conv1'])
# 	(2): 'conv1_1x1' Conv(Frame_CUDA<float>)(nb_inputs=32, nb_outputs=64, kernel_dims=[1, 1], sub_sample_dims=[1, 1], stride_dims=[1, 1], padding_dims=[0, 0], dilation_dims=[1, 1])(['conv1_3x3_dw'])
# 	(3): 'conv2_3x3_dw' Conv(Frame_CUDA<float>)(nb_inputs=64, nb_outputs=64, kernel_dims=[3, 3], sub_sample_dims=[1, 1], stride_dims=[2, 2], padding_dims=[1, 1], dilation_dims=[1, 1])(['conv1_1x1'])
# 	(4): 'conv2_1x1' Conv(Frame_CUDA<float>)(nb_inputs=64, nb_outputs=128, kernel_dims=[1, 1], sub_sample_dims=[1, 1], stride_dims=[1, 1], padding_dims=[0, 0], dilation_dims=[1, 1])(['conv2_3x3_dw'])
# 	(5): 'conv3_3x3_dw' Conv(Frame_CUDA<float>)(nb_inputs=128, nb_outputs=128, kernel_dims=[3, 3], sub_sample_dims=[1, 1], stride_dims=[1, 1], padding_dims=[1, 1], dilation_dims=[1, 1])(['conv2_1x1'])
# 	(6): 'conv3_1x1' Conv(Frame_CUDA<float>)(nb_inputs=128, nb_outputs=128, kernel_dims=[1, 1], sub_sample_dims=[1, 1], stride_dims=[1, 1], padding_dims=[0, 0], dilation_dims=[1, 1])(['conv3_3x3_dw'])
# 	(7): 'conv4_3x3_dw' Conv(Frame_CUDA<float>)(nb_inputs=128, nb_outputs=128, kernel_dims=[3, 3], sub_sample_dims=[1, 1], stride_dims=[2, 2], padding_dims=[1, 1], dilation_dims=[1, 1])(['conv3_1x1'])
# 	(8): 'conv4_1x1' Conv(Frame_CUDA<float>)(nb_inputs=128, nb_outputs=256, kernel_dims=[1, 1], sub_sample_dims=[1, 1], stride_dims=[1, 1], padding_dims=[0, 0], dilation_dims=[1, 1])(['conv4_3x3_dw'])
# 	(9): 'conv5_3x3_dw' Conv(Frame_CUDA<float>)(nb_inputs=256, nb_outputs=256, kernel_dims=[3, 3], sub_sample_dims=[1, 1], stride_dims=[1, 1], padding_dims=[1, 1], dilation_dims=[1, 1])(['conv4_1x1'])
# 	(10): 'conv5_1x1' Conv(Frame_CUDA<float>)(nb_inputs=256, nb_outputs=256, kernel_dims=[1, 1], sub_sample_dims=[1, 1], stride_dims=[1, 1], padding_dims=[0, 0], dilation_dims=[1, 1])(['conv5_3x3_dw'])
# 	(11): 'conv6_3x3_dw' Conv(Frame_CUDA<float>)(nb_inputs=256, nb_outputs=256, kernel_dims=[3, 3], sub_sample_dims=[1, 1], stride_dims=[2, 2], padding_dims=[1, 1], dilation_dims=[1, 1])(['conv5_1x1'])
# 	(12): 'conv6_1x1' Conv(Frame_CUDA<float>)(nb_inputs=256, nb_outputs=512, kernel_dims=[1, 1], sub_sample_dims=[1, 1], stride_dims=[1, 1], padding_dims=[0, 0], dilation_dims=[1, 1])(['conv6_3x3_dw'])
# 	(13): 'conv7_1_3x3_dw' Conv(Frame_CUDA<float>)(nb_inputs=512, nb_outputs=512, kernel_dims=[3, 3], sub_sample_dims=[1, 1], stride_dims=[1, 1], padding_dims=[1, 1], dilation_dims=[1, 1])(['conv6_1x1'])
# 	(14): 'conv7_1_1x1' Conv(Frame_CUDA<float>)(nb_inputs=512, nb_outputs=512, kernel_dims=[1, 1], sub_sample_dims=[1, 1], stride_dims=[1, 1], padding_dims=[0, 0], dilation_dims=[1, 1])(['conv7_1_3x3_dw'])
# 	(15): 'conv7_2_3x3_dw' Conv(Frame_CUDA<float>)(nb_inputs=512, nb_outputs=512, kernel_dims=[3, 3], sub_sample_dims=[1, 1], stride_dims=[1, 1], padding_dims=[1, 1], dilation_dims=[1, 1])(['conv7_1_1x1'])
# 	(16): 'conv7_2_1x1' Conv(Frame_CUDA<float>)(nb_inputs=512, nb_outputs=512, kernel_dims=[1, 1], sub_sample_dims=[1, 1], stride_dims=[1, 1], padding_dims=[0, 0], dilation_dims=[1, 1])(['conv7_2_3x3_dw'])
# 	(17): 'conv7_3_3x3_dw' Conv(Frame_CUDA<float>)(nb_inputs=512, nb_outputs=512, kernel_dims=[3, 3], sub_sample_dims=[1, 1], stride_dims=[1, 1], padding_dims=[1, 1], dilation_dims=[1, 1])(['conv7_2_1x1'])
# 	(18): 'conv7_3_1x1' Conv(Frame_CUDA<float>)(nb_inputs=512, nb_outputs=512, kernel_dims=[1, 1], sub_sample_dims=[1, 1], stride_dims=[1, 1], padding_dims=[0, 0], dilation_dims=[1, 1])(['conv7_3_3x3_dw'])
# 	(19): 'conv7_4_3x3_dw' Conv(Frame_CUDA<float>)(nb_inputs=512, nb_outputs=512, kernel_dims=[3, 3], sub_sample_dims=[1, 1], stride_dims=[1, 1], padding_dims=[1, 1], dilation_dims=[1, 1])(['conv7_3_1x1'])
# 	(20): 'conv7_4_1x1' Conv(Frame_CUDA<float>)(nb_inputs=512, nb_outputs=512, kernel_dims=[1, 1], sub_sample_dims=[1, 1], stride_dims=[1, 1], padding_dims=[0, 0], dilation_dims=[1, 1])(['conv7_4_3x3_dw'])
# 	(21): 'conv7_5_3x3_dw' Conv(Frame_CUDA<float>)(nb_inputs=512, nb_outputs=512, kernel_dims=[3, 3], sub_sample_dims=[1, 1], stride_dims=[1, 1], padding_dims=[1, 1], dilation_dims=[1, 1])(['conv7_4_1x1'])
# 	(22): 'conv7_5_1x1' Conv(Frame_CUDA<float>)(nb_inputs=512, nb_outputs=512, kernel_dims=[1, 1], sub_sample_dims=[1, 1], stride_dims=[1, 1], padding_dims=[0, 0], dilation_dims=[1, 1])(['conv7_5_3x3_dw'])
# 	(23): 'conv8_3x3_dw' Conv(Frame_CUDA<float>)(nb_inputs=512, nb_outputs=512, kernel_dims=[3, 3], sub_sample_dims=[1, 1], stride_dims=[2, 2], padding_dims=[1, 1], dilation_dims=[1, 1])(['conv7_5_1x1'])
# 	(24): 'conv8_1x1' Conv(Frame_CUDA<float>)(nb_inputs=512, nb_outputs=1024, kernel_dims=[1, 1], sub_sample_dims=[1, 1], stride_dims=[1, 1], padding_dims=[0, 0], dilation_dims=[1, 1])(['conv8_3x3_dw'])
# 	(25): 'conv9_3x3_dw' Conv(Frame_CUDA<float>)(nb_inputs=1024, nb_outputs=1024, kernel_dims=[3, 3], sub_sample_dims=[1, 1], stride_dims=[1, 1], padding_dims=[1, 1], dilation_dims=[1, 1])(['conv8_1x1'])
# 	(26): 'conv9_1x1' Conv(Frame_CUDA<float>)(nb_inputs=1024, nb_outputs=1024, kernel_dims=[1, 1], sub_sample_dims=[1, 1], stride_dims=[1, 1], padding_dims=[0, 0], dilation_dims=[1, 1])(['conv9_3x3_dw'])
# 	(27): 'pool1' Pool(Frame_CUDA<float>)(pool_dims=[7, 7], stride_dims=[1, 1], padding_dims=[0, 0], pooling=Pooling.Average)(['conv9_1x1'])
# 	(28): 'fc' Fc(Frame_CUDA<float>)(nb_inputs=1024, nb_outputs=1000)(['pool1'])
# )

# %%
pool = torch.nn.AvgPool2d(7, stride=7)
flatten = torch.nn.Flatten(start_dim=1)
classifier = torch.nn.Linear(1024, len(classes))
head = torch.nn.Sequential(pool, flatten, classifier)
head.to(device)
# Out:
# Sequential(
#   (0): AvgPool2d(kernel_size=7, stride=7, padding=0)
#   (1): Flatten(start_dim=1, end_dim=-1)
#   (2): Linear(in_features=1024, out_features=2, bias=True)
# )

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(head.parameters(), lr = 0.01)

# %%
model = model.eval()
head = head.train()

# %%
epochs = 10
running_loss_history = []
running_corrects_history = []
val_running_loss_history = []
val_running_corrects_history = []

for e in range(epochs):
  
    running_loss = 0.0
    running_corrects = 0.0
    val_running_loss = 0.0
    val_running_corrects = 0.0
    
    for inputs, labels in training_loader:
        inputs = inputs.to(device)
        labels = labels.to(device)

        div4, div8, div16, div32 = model(inputs)
        outputs = head(div32)

        loss = criterion(outputs, labels)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        _, preds = torch.max(outputs, 1)
        running_loss += loss.item()
        running_corrects += torch.sum(preds == labels.data)

    else:
        with torch.no_grad():
            for val_inputs, val_labels in validation_loader:
                val_inputs = val_inputs.to(device)
                val_labels = val_labels.to(device)

                div4, div8, div16, div32 = model(val_inputs)
                val_outputs = head(div32)

                val_loss = criterion(val_outputs, val_labels)
                
                _, val_preds = torch.max(val_outputs, 1)
                val_running_loss += val_loss.item()
                val_running_corrects += torch.sum(val_preds == val_labels.data)
        
        epoch_loss = running_loss/len(training_loader.dataset)
        epoch_acc = running_corrects.float()/ len(training_loader.dataset)
        running_loss_history.append(epoch_loss)
        running_corrects_history.append(epoch_acc)
        
        val_epoch_loss = val_running_loss/len(validation_loader.dataset)
        val_epoch_acc = val_running_corrects.float()/ len(validation_loader.dataset)
        val_running_loss_history.append(val_epoch_loss)
        val_running_corrects_history.append(val_epoch_acc)
        print('epoch :', (e+1))
        print('training loss: {:.4f}, acc {:.4f} '.format(epoch_loss, epoch_acc.item()))
        print('validation loss: {:.4f}, validation acc {:.4f} '.format(val_epoch_loss, val_epoch_acc.item()))
# Out:
# epoch : 1
# training loss: 0.0786, acc 0.5902
# validation loss: 0.0277, validation acc 0.7647
# epoch : 2
# training loss: 0.0273, acc 0.8156
# validation loss: 0.0232, validation acc 0.8235
# epoch : 3
# training loss: 0.0174, acc 0.8648
# validation loss: 0.0172, validation acc 0.8235
# epoch : 4
# training loss: 0.0161, acc 0.8361
# validation loss: 0.0230, validation acc 0.8366
# epoch : 5
# training loss: 0.0156, acc 0.8443
# validation loss: 0.0252, validation acc 0.8366
# epoch : 6
# training loss: 0.0121, acc 0.8689
# validation loss: 0.0168, validation acc 0.8235
# epoch : 7
# training loss: 0.0128, acc 0.8852
# validation loss: 0.0290, validation acc 0.8301
# epoch : 8
# training loss: 0.0179, acc 0.8484
# validation loss: 0.0182, validation acc 0.8301
# epoch : 9
# training loss: 0.0162, acc 0.8607
# validation loss: 0.0281, validation acc 0.7778
# epoch : 10
# training loss: 0.0165, acc 0.8484
# validation loss: 0.0241, validation acc 0.8301

# %%
plt.plot(running_loss_history, label='training loss')
plt.plot(val_running_loss_history, label='validation loss')
plt.legend()

# %%
running_corrects_history = [x.to("cpu") for x in running_corrects_history]
val_running_corrects_history = [x.to("cpu") for x in val_running_corrects_history]

plt.plot(running_corrects_history, label='training accuracy')
plt.plot(val_running_corrects_history, label='validation accuracy')
plt.legend()

# %%
import requests
from PIL import Image

url = 'https://cdn.sci.news/images/enlarge5/image_6425e-Giant-Red-Bull-Ant.jpg'
response = requests.get(url, stream=True)
img = Image.open(response.raw)
plt.imshow(img)

# %%
img = transform(img) 
plt.imshow(im_convert(img))

# %%
model_one_img = NeuroCorgiNet_n2d2_torch([1, 3, 224, 224], weights_dir="../data/imagenet_weights")
# Out:
# Importing NeuroCorgi model in int4 mode.
# Adding cell (extractor) : bn1
# Adding cell (extractor) : bn1_3x3_dw
# Adding cell (extractor) : bn1_1x1
# Adding cell (extractor) : bn2_3x3_dw
# Adding cell (extractor) : bn2_1x1
# Adding cell (extractor) : bn3_3x3_dw
# Adding cell (extractor) : bn3_1x1
# Adding cell (extractor) : bn4_3x3_dw
# Adding cell (extractor) : bn4_1x1
# Adding cell (extractor) : bn5_3x3_dw
# Adding cell (extractor) : bn5_1x1
# Adding cell (extractor) : bn6_3x3_dw
# Adding cell (extractor) : bn6_1x1
# Adding cell (extractor) : bn7_1_3x3_dw
# Adding cell (extractor) : bn7_1_1x1
# Adding cell (extractor) : bn7_2_3x3_dw
# Adding cell (extractor) : bn7_2_1x1
# Adding cell (extractor) : bn7_3_3x3_dw
# Adding cell (extractor) : bn7_3_1x1
# Adding cell (extractor) : bn7_4_3x3_dw
# Adding cell (extractor) : bn7_4_1x1
# Adding cell (extractor) : bn7_5_3x3_dw
# Adding cell (extractor) : bn7_5_1x1
# Adding cell (extractor) : bn8_3x3_dw
# Adding cell (extractor) : bn8_1x1
# Adding cell (extractor) : bn9_3x3_dw
# Adding cell (extractor) : bn9_1x1
# Import ../data/imagenet_weights/conv1.syntxt
# Import ../data/imagenet_weights/conv1_3x3_dw.syntxt
# Import ../data/imagenet_weights/conv1_1x1.syntxt
# Import ../data/imagenet_weights/bn1.syntxt
# Import ../data/imagenet_weights/bn1_3x3_dw.syntxt
# Import ../data/imagenet_weights/bn1_1x1.syntxt
# Import ../data/imagenet_weights/conv2_3x3_dw.syntxt
# Import ../data/imagenet_weights/conv2_1x1.syntxt
# Import ../data/imagenet_weights/conv3_3x3_dw.syntxt
# Import ../data/imagenet_weights/conv3_1x1.syntxt
# Import ../data/imagenet_weights/bn2_3x3_dw.syntxt
# Import ../data/imagenet_weights/bn2_1x1.syntxt
# Import ../data/imagenet_weights/bn3_3x3_dw.syntxt
# Import ../data/imagenet_weights/bn3_1x1.syntxt
# Import ../data/imagenet_weights/conv4_3x3_dw.syntxt
# Import ../data/imagenet_weights/conv4_1x1.syntxt
# Import ../data/imagenet_weights/conv5_3x3_dw.syntxt
# Import ../data/imagenet_weights/conv5_1x1.syntxt
# Import ../data/imagenet_weights/bn4_3x3_dw.syntxt
# Import ../data/imagenet_weights/bn4_1x1.syntxt
# Import ../data/imagenet_weights/bn5_3x3_dw.syntxt
# Import ../data/imagenet_weights/bn5_1x1.syntxt
# Import ../data/imagenet_weights/conv6_3x3_dw.syntxt
# Import ../data/imagenet_weights/conv6_1x1.syntxt
# Import ../data/imagenet_weights/conv7_1_3x3_dw.syntxt
# Import ../data/imagenet_weights/conv7_1_1x1.syntxt
# Import ../data/imagenet_weights/conv7_2_3x3_dw.syntxt
# Import ../data/imagenet_weights/conv7_2_1x1.syntxt
# Import ../data/imagenet_weights/conv7_3_3x3_dw.syntxt
# Import ../data/imagenet_weights/conv7_3_1x1.syntxt
# Import ../data/imagenet_weights/conv7_4_3x3_dw.syntxt
# Import ../data/imagenet_weights/conv7_4_1x1.syntxt
# Import ../data/imagenet_weights/conv7_5_3x3_dw.syntxt
# Import ../data/imagenet_weights/conv7_5_1x1.syntxt
# Import ../data/imagenet_weights/bn6_3x3_dw.syntxt
# Import ../data/imagenet_weights/bn6_1x1.syntxt
# Import ../data/imagenet_weights/bn7_1_3x3_dw.syntxt
# Import ../data/imagenet_weights/bn7_1_1x1.syntxt
# Import ../data/imagenet_weights/bn7_2_3x3_dw.syntxt
# Import ../data/imagenet_weights/bn7_2_1x1.syntxt
# Import ../data/imagenet_weights/bn7_3_3x3_dw.syntxt
# Import ../data/imagenet_weights/bn7_3_1x1.syntxt
# Import ../data/imagenet_weights/bn7_4_3x3_dw.syntxt
# Import ../data/imagenet_weights/bn7_4_1x1.syntxt
# Import ../data/imagenet_weights/bn7_5_3x3_dw.syntxt
# Import ../data/imagenet_weights/bn7_5_1x1.syntxt
# Import ../data/imagenet_weights/conv8_3x3_dw.syntxt
# Import ../data/imagenet_weights/conv8_1x1.syntxt
# Import ../data/imagenet_weights/conv9_3x3_dw.syntxt
# Import ../data/imagenet_weights/conv9_1x1.syntxt
# Import ../data/imagenet_weights/bn8_3x3_dw.syntxt
# Import ../data/imagenet_weights/bn8_1x1.syntxt
# Import ../data/imagenet_weights/bn9_3x3_dw.syntxt
# Import ../data/imagenet_weights/bn9_1x1.syntxt
# Import ../data/imagenet_weights/fc.syntxt
# Applying QAT Fusion...
# Fuse the QAT Graph for hardware compatibility...
# stimuli_stats processing 0 stimuli

# %%
image = img.to(device).unsqueeze(0)
div4, div8, div16, div32 = model_one_img(image)
output = head(div32)
_, pred = torch.max(output, 1)
print(classes[pred.item()])
# Out:
# ant

# %%
dataiter = iter(validation_loader)
images, labels = next(dataiter)
images = images.to(device)
labels = labels.to(device)

div4, div8, div16, div32 = model(images)
output = head(div32)

_, preds = torch.max(output, 1)

fig = plt.figure(figsize=(25, 4))

for idx in np.arange(20):
    ax = fig.add_subplot(2, 10, idx+1, xticks=[], yticks=[])
    plt.imshow(im_convert(images[idx]))
    ax.set_title("{} ({})".format(str(classes[preds[idx].item()]), 
                                  str(classes[labels[idx].item()])), 
                                  color=("green" if preds[idx]==labels[idx] else "red"))
